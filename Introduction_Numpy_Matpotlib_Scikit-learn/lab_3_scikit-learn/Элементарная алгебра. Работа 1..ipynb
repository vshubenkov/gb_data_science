# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
#y(k,x)=cos(k∙x)

# %%
k=1
plt.plot(np.linspace(0,20,200),np.cos(np.linspace(0,20,200)*k))
k=0.5
plt.plot(np.linspace(0,20,200),np.cos(np.linspace(0,20,200)*k))
plt.legend(labels=['k1','k3'])
